# %%
# THIS IS FOR CLIENT

# %%
import boto3
ec2_cli = boto3.client('ec2')
#print(dir(ec2_cli))
for each in dir(ec2_cli):
    print(each)
# Out:
# _PY_TO_OP_NAME
# __class__
# __delattr__
# __dict__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattr__
# __getattribute__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __le__
# __lt__
# __module__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __sizeof__
# __str__
# __subclasshook__
# __weakref__
# _cache
# _client_config
# _convert_to_request_dict
# _emit_api_params
# _endpoint
# _exceptions
# _exceptions_factory
# _get_waiter_config
# _load_exceptions
# _loader
# _make_api_call
# _make_request
# _register_handlers
# _request_signer
# _resolve_endpoint_ruleset
# _response_parser
# _ruleset_resolver
# _serializer
# _service_model
# _user_agent_creator
# accept_address_transfer
# accept_reserved_instances_exchange_quote
# accept_transit_gateway_multicast_domain_associations
# accept_transit_gateway_peering_attachment
# accept_transit_gateway_vpc_attachment
# accept_vpc_endpoint_connections
# accept_vpc_peering_connection
# ...

# %%
import boto3
ec2_cli = boto3.client('ec2')
print(ec2_cli.describe_instances())
# Out:
# {'Reservations': [{'Groups': [], 'Instances': [{'AmiLaunchIndex': 0, 'ImageId': 'ami-0287a05f0ef0e9d9a', 'InstanceId': 'i-010c868943eb9fcd9', 'InstanceType': 't2.micro', 'KeyName': 'august', 'LaunchTime': datetime.datetime(2023, 11, 25, 14, 45, 8, tzinfo=tzutc()), 'Monitoring': {'State': 'disabled'}, 'Placement': {'AvailabilityZone': 'ap-south-1b', 'GroupName': '', 'Tenancy': 'default'}, 'PrivateDnsName': 'ip-172-31-6-134.ap-south-1.compute.internal', 'PrivateIpAddress': '172.31.6.134', 'ProductCodes': [], 'PublicDnsName': '', 'State': {'Code': 80, 'Name': 'stopped'}, 'StateTransitionReason': 'User initiated (2023-11-25 14:48:18 GMT)', 'SubnetId': 'subnet-05d902d4dd9ad6ea2', 'VpcId': 'vpc-0d523b1c2f75851ab', 'Architecture': 'x86_64', 'BlockDeviceMappings': [{'DeviceName': '/dev/sda1', 'Ebs': {'AttachTime': datetime.datetime(2023, 11, 25, 7, 21, 1, tzinfo=tzutc()), 'DeleteOnTermination': True, 'Status': 'attached', 'VolumeId': 'vol-098383fa038e6e9f5'}}], 'ClientToken': '902d52de-626d-
# ...

# %%
import boto3
ec2_cli = boto3.client('ec2')
for each in ec2_cli.describe_instances():
    print(each)
    break
# Out:
# Reservations

# %%
import boto3
ec2_cli = boto3.client('ec2')
for each in ec2_cli.describe_instances()['Reservations']:
    print(each)
    break
# Out:
# {'Groups': [], 'Instances': [{'AmiLaunchIndex': 0, 'ImageId': 'ami-0287a05f0ef0e9d9a', 'InstanceId': 'i-010c868943eb9fcd9', 'InstanceType': 't2.micro', 'KeyName': 'august', 'LaunchTime': datetime.datetime(2023, 11, 25, 14, 45, 8, tzinfo=tzutc()), 'Monitoring': {'State': 'disabled'}, 'Placement': {'AvailabilityZone': 'ap-south-1b', 'GroupName': '', 'Tenancy': 'default'}, 'PrivateDnsName': 'ip-172-31-6-134.ap-south-1.compute.internal', 'PrivateIpAddress': '172.31.6.134', 'ProductCodes': [], 'PublicDnsName': '', 'State': {'Code': 80, 'Name': 'stopped'}, 'StateTransitionReason': 'User initiated (2023-11-25 14:48:18 GMT)', 'SubnetId': 'subnet-05d902d4dd9ad6ea2', 'VpcId': 'vpc-0d523b1c2f75851ab', 'Architecture': 'x86_64', 'BlockDeviceMappings': [{'DeviceName': '/dev/sda1', 'Ebs': {'AttachTime': datetime.datetime(2023, 11, 25, 7, 21, 1, tzinfo=tzutc()), 'DeleteOnTermination': True, 'Status': 'attached', 'VolumeId': 'vol-098383fa038e6e9f5'}}], 'ClientToken': '902d52de-626d-4852-ab44-86cd6bc1
# ...

# %%
import boto3
import pprint
ec2_cli = boto3.client('ec2')
for each in ec2_cli.describe_instances()['Reservations']:
    pprint.pprint(each['Instances'])
    break
# Out:
# [{'AmiLaunchIndex': 0,
#   'Architecture': 'x86_64',
#   'BlockDeviceMappings': [{'DeviceName': '/dev/sda1',
#                            'Ebs': {'AttachTime': datetime.datetime(2023, 11, 25, 7, 21, 1, tzinfo=tzutc()),
#                                    'DeleteOnTermination': True,
#                                    'Status': 'attached',
#                                    'VolumeId': 'vol-098383fa038e6e9f5'}}],
#   'CapacityReservationSpecification': {'CapacityReservationPreference': 'open'},
#   'ClientToken': '902d52de-626d-4852-ab44-86cd6bc13a94',
#   'CpuOptions': {'CoreCount': 1, 'ThreadsPerCore': 1},
#   'CurrentInstanceBootMode': 'legacy-bios',
#   'EbsOptimized': False,
#   'EnaSupport': True,
#   'EnclaveOptions': {'Enabled': False},
#   'HibernationOptions': {'Configured': False},
#   'Hypervisor': 'xen',
#   'ImageId': 'ami-0287a05f0ef0e9d9a',
#   'InstanceId': 'i-010c868943eb9fcd9',
#   'InstanceType': 't2.micro',
#   'KeyName': 'august',
# ...

# %%
import boto3
import pprint
ec2_cli = boto3.client('ec2')
for each in ec2_cli.describe_instances()['Reservations']:# here we got the list
    for each_in in each['Instances']: # here we got the dictionary
        pprint.pprint(each_in)
        break
    break
# Out:
# {'AmiLaunchIndex': 0,
#  'Architecture': 'x86_64',
#  'BlockDeviceMappings': [{'DeviceName': '/dev/sda1',
#                           'Ebs': {'AttachTime': datetime.datetime(2023, 11, 25, 7, 21, 1, tzinfo=tzutc()),
#                                   'DeleteOnTermination': True,
#                                   'Status': 'attached',
#                                   'VolumeId': 'vol-098383fa038e6e9f5'}}],
#  'CapacityReservationSpecification': {'CapacityReservationPreference': 'open'},
#  'ClientToken': '902d52de-626d-4852-ab44-86cd6bc13a94',
#  'CpuOptions': {'CoreCount': 1, 'ThreadsPerCore': 1},
#  'CurrentInstanceBootMode': 'legacy-bios',
#  'EbsOptimized': False,
#  'EnaSupport': True,
#  'EnclaveOptions': {'Enabled': False},
#  'HibernationOptions': {'Configured': False},
#  'Hypervisor': 'xen',
#  'ImageId': 'ami-0287a05f0ef0e9d9a',
#  'InstanceId': 'i-010c868943eb9fcd9',
#  'InstanceType': 't2.micro',
#  'KeyName': 'august',
# ...

# %%
import boto3
import pprint
ec2_cli = boto3.client('ec2')
for each in ec2_cli.describe_instances()['Reservations']:# here we got the list
    for each_in in each['Instances']: # here we got the dictionary
        pprint.pprint(each_in['Tags']) #checkin for tags 
        break
    break
# Out:
# [{'Key': 'Name', 'Value': 'docker'}]

# %%
import boto3
import pprint
ec2_cli = boto3.client('ec2')
for each in ec2_cli.describe_instances()['Reservations']:# here we got the list
    for each_in in each['Instances']: # here we got the dictionary
        print(each_in['Tags'][0]['Value']) #checkin for tags 
        break
    break
# Out:
# docker

# %%
import boto3
import pprint
ec2_cli = boto3.client('ec2')
for each in ec2_cli.describe_instances()['Reservations']:# here we got the list
    for each_in in each['Instances']: # here we got the dictionary
        print(each_in['InstanceId']) # to get the instance id
# Out:
# i-010c868943eb9fcd9
# i-08df3fb5a12827c80
# i-0f3ebec0d98a4779c
# i-0d9493fd600e9673c
# i-0377a1c7b349bd9e8

# %%
import boto3
import pprint
ec2_cli = boto3.client('ec2')
for each in ec2_cli.describe_instances()['Reservations']:# here we got the list
    for each_in in each['Instances']: # here we got the dictionary
        print(each_in['InstanceId'],each_in['Tags']) # to get the instance id
# Out:
# i-010c868943eb9fcd9 [{'Key': 'Name', 'Value': 'docker'}]
# i-08df3fb5a12827c80 [{'Key': 'Name', 'Value': 'jenkins_2048'}]
# i-0f3ebec0d98a4779c [{'Key': 'Name', 'Value': 'slavea'}]
# i-0d9493fd600e9673c [{'Key': 'Name', 'Value': 'slaveb'}]
# i-0377a1c7b349bd9e8 [{'Key': 'Name', 'Value': 'master'}]

# %%
import boto3
import pprint
ec2_cli = boto3.client('ec2')
for each in ec2_cli.describe_instances()['Reservations']:# here we got the list
    for each_in in each['Instances']: # here we got the dictionary
        print(each_in['InstanceId'],each_in[Tags['Value']]) # to get the instance id
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 6
#       4 for each in ec2_cli.describe_instances()['Reservations']:# here we got the list
#       5     for each_in in each['Instances']: # here we got the dictionary
# ----> 6         print(each_in['InstanceId'],each_in[Tags['Value']]) # to get the instance id
#
# NameError: name 'Tags' is not defined
