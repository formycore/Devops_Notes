# %%
import boto3
ec2_re = boto3.resource('ec2')
print(dir(ec2_re))
# Out:
# ['ClassicAddress', 'DhcpOptions', 'Image', 'Instance', 'InternetGateway', 'KeyPair', 'NetworkAcl', 'NetworkInterface', 'NetworkInterfaceAssociation', 'PlacementGroup', 'Route', 'RouteTable', 'RouteTableAssociation', 'SecurityGroup', 'Snapshot', 'Subnet', 'Tag', 'Volume', 'Vpc', 'VpcAddress', 'VpcPeeringConnection', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'classic_addresses', 'create_dhcp_options', 'create_instances', 'create_internet_gateway', 'create_key_pair', 'create_network_acl', 'create_network_interface', 'create_placement_group', 'create_route_table', 'create_security_group', 'create_snapshot', 'create_subnet', 'create_tags', 'create_volume', 'create_vpc', 'create_vpc_peering_co
# ...

# %%
# we can get all these with ec2_re
'classic_addresses', 'create_dhcp_options', 'create_instances', 'create_internet_gateway', 'create_key_pair', 'create_network_acl', 'create_network_interface', 'create_placement_group', 'create_route_table', 'create_security_group', 'create_snapshot', 'create_subnet', 'create_tags', 'create_volume', 'create_vpc', 'create_vpc_peering_connection', 'dhcp_options_sets', 'disassociate_route_table', 'get_available_subresources', 'images', 'import_key_pair', 'instances', 'internet_gateways', 'key_pairs', 'meta', 'network_acls', 'network_interfaces', 'placement_groups', 'register_image', 'route_tables', 'security_groups', 'snapshots', 'subnets', 'volumes', 'vpc_addresses', 'vpc_peering_connections', 'vpcs

# %%
print(dir(ec2_re.instances))
print(type(ec2_re.instances))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_collection_cls', '_handler', '_model', '_parent', 'all', 'create_tags', 'filter', 'iterator', 'limit', 'monitor', 'page_size', 'pages', 'reboot', 'start', 'stop', 'terminate', 'unmonitor']
# <class 'boto3.resources.collection.ec2.instancesCollectionManager'>

# %%
print(dir(ec2_re.instances()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(dir(ec2_re.instances()))
#
# TypeError: 'ec2.instancesCollectionManager' object is not callable

# %%
print(dir(ec2_re.instances.all()))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_clone', '_handler', '_model', '_params', '_parent', '_py_operation_name', 'all', 'create_tags', 'filter', 'limit', 'monitor', 'page_size', 'pages', 'reboot', 'start', 'stop', 'terminate', 'unmonitor']

# %%
import boto3
ec2_re = boto3.resource('ec2')
for each in ec2_re.instances.all():
    print(each)
    print("this is type of ", type(each))
# Out:
# ec2.Instance(id='i-010c868943eb9fcd9')
# this is type of  <class 'boto3.resources.factory.ec2.Instance'>
# ec2.Instance(id='i-08df3fb5a12827c80')
# this is type of  <class 'boto3.resources.factory.ec2.Instance'>
# ec2.Instance(id='i-0f3ebec0d98a4779c')
# this is type of  <class 'boto3.resources.factory.ec2.Instance'>
# ec2.Instance(id='i-0d9493fd600e9673c')
# this is type of  <class 'boto3.resources.factory.ec2.Instance'>
# ec2.Instance(id='i-0377a1c7b349bd9e8')
# this is type of  <class 'boto3.resources.factory.ec2.Instance'>

# %%
import boto3
ec2_re = boto3.resource('ec2')
for each in ec2_re.instances.all():
    print(dir(each))
    break
# NOW FROM EACH WE CAN MANAGE THESE OPERATIONS
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_id', 'ami_launch_index', 'architecture', 'attach_classic_link_vpc', 'attach_volume', 'block_device_mappings', 'boot_mode', 'capacity_reservation_id', 'capacity_reservation_specification', 'classic_address', 'client_token', 'console_output', 'cpu_options', 'create_image', 'create_tags', 'current_instance_boot_mode', 'delete_tags', 'describe_attribute', 'detach_classic_link_vpc', 'detach_volume', 'ebs_optimized', 'elastic_gpu_associations', 'elastic_inference_accelerator_associations', 'ena_support', 'enclave_options', 'get_available_subresources', 'hibernation_options', 'hypervisor', 'iam_instance_profile', 'id', 'image', 'image_id', 'instance_
# ...

# %%
import boto3
ec2_re = boto3.resource('ec2')
for each in ec2_re.instances.all():
    print(each.tags[0]['Value'])
# Out:
# docker
# jenkins_2048
# slavea
# slaveb
# master

# %%
import boto3
ec2_re = boto3.resource('ec2')
for each in ec2_re.instances.all():
    if each.tags[0]['Value'] == 'docker':
        each.start()

# %%
# Start the docker machine and get the ip address
import boto3
ec2_re = boto3.resource('ec2')
for each in ec2_re.instances.all():
    if each.tags[0]['Value'] == 'docker':
        each.start()
        print(each.public_ip_address)
# Out:
# 13.232.96.199

# %%
import boto3
ec2_re = boto3.resource('ec2')
for each in ec2_re.instances.all():
    if each.tags[0]['Value'] == 'docker':
        each.stop()

# %%
# Out:
# {'Reservations': [{'Groups': [], 'Instances': [{'AmiLaunchIndex': 0, 'ImageId': 'ami-0287a05f0ef0e9d9a', 'InstanceId': 'i-010c868943eb9fcd9', 'InstanceType': 't2.micro', 'KeyName': 'august', 'LaunchTime': datetime.datetime(2023, 11, 25, 14, 45, 8, tzinfo=tzutc()), 'Monitoring': {'State': 'disabled'}, 'Placement': {'AvailabilityZone': 'ap-south-1b', 'GroupName': '', 'Tenancy': 'default'}, 'PrivateDnsName': 'ip-172-31-6-134.ap-south-1.compute.internal', 'PrivateIpAddress': '172.31.6.134', 'ProductCodes': [], 'PublicDnsName': '', 'State': {'Code': 80, 'Name': 'stopped'}, 'StateTransitionReason': 'User initiated (2023-11-25 14:48:18 GMT)', 'SubnetId': 'subnet-05d902d4dd9ad6ea2', 'VpcId': 'vpc-0d523b1c2f75851ab', 'Architecture': 'x86_64', 'BlockDeviceMappings': [{'DeviceName': '/dev/sda1', 'Ebs': {'AttachTime': datetime.datetime(2023, 11, 25, 7, 21, 1, tzinfo=tzutc()), 'DeleteOnTermination': True, 'Status': 'attached', 'VolumeId': 'vol-098383fa038e6e9f5'}}], 'ClientToken': '902d52de-626d-
# ...

# %%
import boto3
ec2_cli = boto3.client('ec2')
print(ec2_cli.describe_instances()['Reservations'])
# Out:
# [{'Groups': [], 'Instances': [{'AmiLaunchIndex': 0, 'ImageId': 'ami-0287a05f0ef0e9d9a', 'InstanceId': 'i-010c868943eb9fcd9', 'InstanceType': 't2.micro', 'KeyName': 'august', 'LaunchTime': datetime.datetime(2023, 11, 25, 14, 45, 8, tzinfo=tzutc()), 'Monitoring': {'State': 'disabled'}, 'Placement': {'AvailabilityZone': 'ap-south-1b', 'GroupName': '', 'Tenancy': 'default'}, 'PrivateDnsName': 'ip-172-31-6-134.ap-south-1.compute.internal', 'PrivateIpAddress': '172.31.6.134', 'ProductCodes': [], 'PublicDnsName': '', 'State': {'Code': 80, 'Name': 'stopped'}, 'StateTransitionReason': 'User initiated (2023-11-25 14:48:18 GMT)', 'SubnetId': 'subnet-05d902d4dd9ad6ea2', 'VpcId': 'vpc-0d523b1c2f75851ab', 'Architecture': 'x86_64', 'BlockDeviceMappings': [{'DeviceName': '/dev/sda1', 'Ebs': {'AttachTime': datetime.datetime(2023, 11, 25, 7, 21, 1, tzinfo=tzutc()), 'DeleteOnTermination': True, 'Status': 'attached', 'VolumeId': 'vol-098383fa038e6e9f5'}}], 'ClientToken': '902d52de-626d-4852-ab44-86cd6bc
# ...

# %%
import boto3
import pprint
ec2_cli = boto3.client('ec2')
for each in ec2_cli.describe_instances()['Reservations']:
    for each_in in each['Instances']:
        pprint.pprint(each_in)
        break
# Out:
# {'AmiLaunchIndex': 0,
#  'Architecture': 'x86_64',
#  'BlockDeviceMappings': [{'DeviceName': '/dev/sda1',
#                           'Ebs': {'AttachTime': datetime.datetime(2023, 11, 25, 7, 21, 1, tzinfo=tzutc()),
#                                   'DeleteOnTermination': True,
#                                   'Status': 'attached',
#                                   'VolumeId': 'vol-098383fa038e6e9f5'}}],
#  'CapacityReservationSpecification': {'CapacityReservationPreference': 'open'},
#  'ClientToken': '902d52de-626d-4852-ab44-86cd6bc13a94',
#  'CpuOptions': {'CoreCount': 1, 'ThreadsPerCore': 1},
#  'CurrentInstanceBootMode': 'legacy-bios',
#  'EbsOptimized': False,
#  'EnaSupport': True,
#  'EnclaveOptions': {'Enabled': False},
#  'HibernationOptions': {'Configured': False},
#  'Hypervisor': 'xen',
#  'ImageId': 'ami-0287a05f0ef0e9d9a',
#  'InstanceId': 'i-010c868943eb9fcd9',
#  'InstanceType': 't2.micro',
#  'KeyName': 'august',
# ...

# %%
import boto3
ec2_cli = boto3.client('ec2')
for each in ec2_cli.describe_instances():

# %%
import boto3
ec2_cli = boto3.client('ec2')
tag_key = 'Name'
tag_value = 'docker'
# Describe the instance based on the specific tags
response = ec2_cli.describe_instances(Filters=[{'Name':f'tag:{tag_key}','Values': [tag_value]}])
# Start the instances until it is running
for reservation in response['Reservations']:
    print(reservation)
#     for instance in reservation['Instances']:
#         print(instance['InstanceId'])

# %%
import boto3
import pprint
ec2_cli = boto3.client('ec2')
tag_key = 'Name'
tag_value = 'docker'
# Describe the instance based on the specific tags
#response = ec2_cli.describe_instances(Filters=[{'Name':f'tag:{tag_key}','Values': [tag_value]}])
response = ec2_cli.describe_instances()
# Start the instances until it is running
for reservation in response['Reservations']:
    pprint.pprint(reservation)
# Out:
# {'Groups': [],
#  'Instances': [{'AmiLaunchIndex': 0,
#                 'Architecture': 'x86_64',
#                 'BlockDeviceMappings': [{'DeviceName': '/dev/sda1',
#                                          'Ebs': {'AttachTime': datetime.datetime(2023, 11, 25, 7, 21, 1, tzinfo=tzutc()),
#                                                  'DeleteOnTermination': True,
#                                                  'Status': 'attached',
#                                                  'VolumeId': 'vol-098383fa038e6e9f5'}}],
#                 'CapacityReservationSpecification': {'CapacityReservationPreference': 'open'},
#                 'ClientToken': '902d52de-626d-4852-ab44-86cd6bc13a94',
#                 'CpuOptions': {'CoreCount': 1, 'ThreadsPerCore': 1},
#                 'CurrentInstanceBootMode': 'legacy-bios',
#                 'EbsOptimized': False,
#                 'EnaSupport': True,
#                 'EnclaveOptions': {'Enabled': False},
# ...

# %%
import boto3
ec2_cli = boto3.client('ec2')
tag_key = 'Name'
tag_value = 'docker'
# Describe the instance based on the specific tags
#response = ec2_cli.describe_instances(Filters=[{'Name':f'tag:{tag_key}','Values': [tag_value]}])
response = ec2_cli.describe_instances()
# Start the instances until it is running
for reservation in response['Reservations']:
    #print(reservation) # this is a dictionary
    print(reservation['Instances'])
    # output is a list then again a iteration
# Out:
# [{'AmiLaunchIndex': 0, 'ImageId': 'ami-0287a05f0ef0e9d9a', 'InstanceId': 'i-010c868943eb9fcd9', 'InstanceType': 't2.micro', 'KeyName': 'august', 'LaunchTime': datetime.datetime(2023, 11, 25, 16, 50, 19, tzinfo=tzutc()), 'Monitoring': {'State': 'disabled'}, 'Placement': {'AvailabilityZone': 'ap-south-1b', 'GroupName': '', 'Tenancy': 'default'}, 'PrivateDnsName': 'ip-172-31-6-134.ap-south-1.compute.internal', 'PrivateIpAddress': '172.31.6.134', 'ProductCodes': [], 'PublicDnsName': '', 'State': {'Code': 80, 'Name': 'stopped'}, 'StateTransitionReason': 'User initiated (2023-11-25 17:12:59 GMT)', 'SubnetId': 'subnet-05d902d4dd9ad6ea2', 'VpcId': 'vpc-0d523b1c2f75851ab', 'Architecture': 'x86_64', 'BlockDeviceMappings': [{'DeviceName': '/dev/sda1', 'Ebs': {'AttachTime': datetime.datetime(2023, 11, 25, 7, 21, 1, tzinfo=tzutc()), 'DeleteOnTermination': True, 'Status': 'attached', 'VolumeId': 'vol-098383fa038e6e9f5'}}], 'ClientToken': '902d52de-626d-4852-ab44-86cd6bc13a94', 'EbsOptimized': Fals
# ...

# %%
import boto3
import pprint
ec2_cli = boto3.client('ec2')
tag_key = 'Name'
tag_value = 'docker'
# Describe the instance based on the specific tags
#response = ec2_cli.describe_instances(Filters=[{'Name':f'tag:{tag_key}','Values': [tag_value]}])
response = ec2_cli.describe_instances()
# Start the instances until it is running
for reservation in response['Reservations']:
    #print(reservation) # this is a dictionary
    for instance in reservation['Instances']:
        pprint.pprint(instance)
# Out:
# {'AmiLaunchIndex': 0,
#  'Architecture': 'x86_64',
#  'BlockDeviceMappings': [{'DeviceName': '/dev/sda1',
#                           'Ebs': {'AttachTime': datetime.datetime(2023, 11, 25, 7, 21, 1, tzinfo=tzutc()),
#                                   'DeleteOnTermination': True,
#                                   'Status': 'attached',
#                                   'VolumeId': 'vol-098383fa038e6e9f5'}}],
#  'CapacityReservationSpecification': {'CapacityReservationPreference': 'open'},
#  'ClientToken': '902d52de-626d-4852-ab44-86cd6bc13a94',
#  'CpuOptions': {'CoreCount': 1, 'ThreadsPerCore': 1},
#  'CurrentInstanceBootMode': 'legacy-bios',
#  'EbsOptimized': False,
#  'EnaSupport': True,
#  'EnclaveOptions': {'Enabled': False},
#  'HibernationOptions': {'Configured': False},
#  'Hypervisor': 'xen',
#  'ImageId': 'ami-0287a05f0ef0e9d9a',
#  'InstanceId': 'i-010c868943eb9fcd9',
#  'InstanceType': 't2.micro',
#  'KeyName': 'august',
# ...

# %%
import boto3
import pprint
ec2_cli = boto3.client('ec2')
# tag_key = 'Name'
# tag_value = 'docker'
# Describe the instance based on the specific tags
#response = ec2_cli.describe_instances(Filters=[{'Name':f'tag:{tag_key}','Values': [tag_value]}])
response = ec2_cli.describe_instances()
# Start the instances until it is running
for reservation in response['Reservations']:
    #print(reservation) # this is a dictionary
    for instance in reservation['Instances']:
        print(instance['InstanceId'],instance['Tags'])
# Out:
# i-010c868943eb9fcd9 [{'Key': 'Name', 'Value': 'docker'}]
# i-08df3fb5a12827c80 [{'Key': 'Name', 'Value': 'jenkins_2048'}]
# i-0f3ebec0d98a4779c [{'Key': 'Name', 'Value': 'slavea'}]
# i-0d9493fd600e9673c [{'Key': 'Name', 'Value': 'slaveb'}]
# i-0377a1c7b349bd9e8 [{'Key': 'Name', 'Value': 'master'}]

# %%
import boto3
import pprint
ec2_cli = boto3.client('ec2')
# tag_key = 'Name'
# tag_value = 'docker'
# Describe the instance based on the specific tags
#response = ec2_cli.describe_instances(Filters=[{'Name':f'tag:{tag_key}','Values': [tag_value]}])
response = ec2_cli.describe_instances()
# Start the instances until it is running
for reservation in response['Reservations']:
    #print(reservation) # this is a dictionary
    for instance in reservation['Instances']:
        #print(instance['InstanceId'],instance['Tags'])
        instance_id = instance['InstanceId']
        tags = instance['Tags']
# Out:
# i-010c868943eb9fcd9 [{'Key': 'Name', 'Value': 'docker'}]
# i-08df3fb5a12827c80 [{'Key': 'Name', 'Value': 'jenkins_2048'}]
# i-0f3ebec0d98a4779c [{'Key': 'Name', 'Value': 'slavea'}]
# i-0d9493fd600e9673c [{'Key': 'Name', 'Value': 'slaveb'}]
# i-0377a1c7b349bd9e8 [{'Key': 'Name', 'Value': 'master'}]
