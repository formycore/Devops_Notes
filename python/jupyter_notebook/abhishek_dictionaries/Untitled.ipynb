# %%
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# /repos/{owner}/{repo}/pulls
# /repos/kubernetes/kubernetes/pulls
# /repos/organization/repo_name
# api.github.com/repos/kubernetes/kubernetes/pulls
# there are like 29 elements for the above url

# %%
import requests
import json
response = requests.get("https://api.github.com/repos/kubernetes/kubernetes/pulls")
# checking the type of the output
print(type(response)) # this is a class or object 
# status of the response if it is 200 is good
print(response)
# print the values in json
print(response.json())
# Out:
# <class 'requests.models.Response'>
# <Response [200]>
# ...

# %%
import requests
import json
response = requests.get("https://api.github.com/repos/kubernetes/kubernetes/pulls")
# checking the type of the output
#print(type(response)) # this is a class or object 
# status of the response if it is 200 is good
#print(response)
# print the values in json
#print(response.json())
# for i in response.json(): # becoz it is a dictionary it has two elemnets
#     print(i)

# %%
import requests
import json
response = requests.get("https://api.github.com/repos/kubernetes/kubernetes/pulls")
print(response.json()[0])
# Out:
# {'url': 'https://api.github.com/repos/kubernetes/kubernetes/pulls/121983', 'id': 1610955774, 'node_id': 'PR_kwDOAToIks5gBTv-', 'html_url': 'https://github.com/kubernetes/kubernetes/pull/121983', 'diff_url': 'https://github.com/kubernetes/kubernetes/pull/121983.diff', 'patch_url': 'https://github.com/kubernetes/kubernetes/pull/121983.patch', 'issue_url': 'https://api.github.com/repos/kubernetes/kubernetes/issues/121983', 'number': 121983, 'state': 'open', 'locked': False, 'title': 'cleanup: remove getStorageAccountName warning messages', 'user': {'login': 'andyzhangx', 'id': 4178417, 'node_id': 'MDQ6VXNlcjQxNzg0MTc=', 'avatar_url': 'https://avatars.githubusercontent.com/u/4178417?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/andyzhangx', 'html_url': 'https://github.com/andyzhangx', 'followers_url': 'https://api.github.com/users/andyzhangx/followers', 'following_url': 'https://api.github.com/users/andyzhangx/following{/other_user}', 'gists_url': 'https://api.github.com/
# ...

# %%
import requests
import json
response = requests.get("https://api.github.com/repos/kubernetes/kubernetes/pulls")
print(response.json()[0]["id"])
print(response.json()[0]["node_id"])
print(response.json()[0]["user"]["login"])
# Out:
# 1610955774
# PR_kwDOAToIks5gBTv-
# andyzhangx

# %%
import requests
response = requests.get("https://api.github.com/repos/kubernetes/kubernetes/pulls")
for i in range(len(response.json())):
    print(response.json()[i]["user"]["login"])
# Out:
# andyzhangx
# utam0k
# linxiulei
# carlory
# pacoxu
# aojea
# pohly
# Peac36
# torredil
# my-git9
# kannon92
# neolit123
# linxiulei
# rewanthtammana
# AxeZhan
# utam0k
# sanposhiho
# sanposhiho
# liggitt
# ardaguclu
# andyzhangx
# andyzhangx
# andyzhangx
# tenzen-y
# Jefftree
# vlasebian
# uablrek
# alexanderConstantinescu
# agxmaster
# saschagrunert
